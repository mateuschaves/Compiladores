# %% [markdown]
# <b>Seja o autômato A:</b>

# %% [markdown]
# ![automato.png](attachment:automato.png)

# %% [markdown]
# <b>A: Conjunto completo de estados Q = $\{ q0, q1, q2 \}$</b>

# %% [markdown]
# $i:$<b>Conjunto unitário de estados iniciais</b> $\{q0\}$

# %% [markdown]
# $\sum:$ <b>Alfabeto reconhecido</b> $\{a, b\}$

# %% [markdown]
# $\delta:$ <b>Tuplas de transição</b>$\{(q0, a, q0), (q0, b, q1), (q1, b, q2), (q2, b, q1)\}$
